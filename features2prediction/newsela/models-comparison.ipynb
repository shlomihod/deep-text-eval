# %%
import glob
import pandas as pd
import pylab as plt
import seaborn as sns

# %%
evaluation = (pd.concat([pd.read_excel(path)
            .assign(type=path[:-16]) for path in glob.glob('*_evaluation.xlsx')], sort=True)
 .reset_index(False)
 .rename({'index': 'name'}, axis=1))

def get_model_family(name):
    if name.startswith('MLP'):
        return 'Neural'
    elif name.startswith('GradientBoosting') or name.startswith('RandomForest'):
        return 'Tree'
    else:
        return 'Linear'
    
evaluation['family'] = evaluation['name'].apply(get_model_family)

# %%
evaluation.sort_values('threshold_socre', ascending=False)
# Out:
#                           name  accuracy_score  explained_variance_score  \
# 14                    MLP-deep          0.6484                    0.7362
# 15                     SVC rbf          0.6415                    0.7296
# 25                     MLP 128          0.5192                    0.6951
# 26                      MLP 64          0.5522                    0.6822
# 16                      MLP 32          0.6030                    0.6993
# 17                      MLP 64          0.5893                    0.7017
# 27                      MLP 32          0.5165                    0.6715
# 28                      MLP 16          0.5440                    0.6829
# 29                    MLP-deep          0.5975                    0.7030
# 2                     MLP-deep          0.6868                       NaN
# 30                     SVR rbf          0.5151                    0.6672
# 18                     MLP 128          0.6154                    0.6972
# 19                      MLP 16          0.5742                    0.6936
# 3   GradientBoostingClassifier          0.7102                       NaN
# 4                       MLP 16          0.6896                       NaN
# 5                       MLP 32          0.6882                       NaN
# 6                      SVC rbf          0.7088                       NaN
# 20  GradientBoostingClassifier          0.5810                    0.6819
# 21        LogisticRegressionCV          0.5591                    0.6734
# 31   GradientBoostingRegressor          0.4698                    0.6237
# 38                         LAD          0.4821                       NaN
# 7                     SVC poly          0.6799                       NaN
# 0                   LogisticAT          0.4588                    0.6308
# 8         LogisticRegressionCV          0.6854                       NaN
# 32                   LinearSVR          0.4753                    0.5824
# 10                     MLP 128          0.6896                       NaN
# 9                    LinearSVC          0.6772                       NaN
# 11                      MLP 64          0.6868                       NaN
# 39                  LogisticAT          0.4629                       NaN
# 40                OrdinalRidge          0.4533                       NaN
# 33            LinearRegression          0.4533                    0.5800
# 34                     LassoCV          0.4547                    0.5810
# 35                     RidgeCV          0.4519                    0.5805
# 1                   LogisticIT          0.3832                    0.5486
# 22                    SVC poly          0.5014                    0.6335
# 12      RandomForestClassifier          0.6690                       NaN
# 23      RandomForestClassifier          0.4245                    0.5569
# 24                 SVC sigmoid          0.4766                    0.5384
# 41                  LogisticIT          0.4945                       NaN
# 13                 SVC sigmoid          0.6236                       NaN
# 36                 SVR sigmoid          0.3132                    0.3895
# 37                    SVR poly          0.2898                    0.0451
#
#     f1_score_micro  mean_absolute_error  mean_squared_error  r2_score  \
# 14          0.6484               0.4923              0.5122    0.7351
# 15          0.6415               0.4904              0.5233    0.7294
# 25          0.5192               0.5999              0.5908    0.6945
# 26          0.5522               0.5971              0.6146    0.6822
# 16          0.6030               0.5436              0.5815    0.6993
# 17          0.5893               0.5420              0.5772    0.7015
# 27          0.5165               0.6252              0.6409    0.6686
# 28          0.5440               0.5961              0.6132    0.6829
# 29          0.5975               0.5397              0.5753    0.7025
# 2           0.6868                  NaN                 NaN       NaN
# 30          0.5151               0.6131              0.6437    0.6671
# 18          0.6154               0.5348              0.5858    0.6970
# 19          0.5742               0.5548              0.5930    0.6933
# 3           0.7102                  NaN                 NaN       NaN
# 4           0.6896                  NaN                 NaN       NaN
# 5           0.6882                  NaN                 NaN       NaN
# 6           0.7088                  NaN                 NaN       NaN
# 20          0.5810               0.5595              0.6152    0.6819
# 21          0.5591               0.5889              0.6321    0.6731
# 31          0.4698               0.6638              0.7279    0.6236
# 38          0.4821               0.6044                 NaN       NaN
# 7           0.6799                  NaN                 NaN       NaN
# 0           0.4588               0.6627              0.7144    0.6305
# 8           0.6854                  NaN                 NaN       NaN
# 32          0.4753               0.7088              0.8075    0.5824
# 10          0.6896                  NaN                 NaN       NaN
# 9           0.6772                  NaN                 NaN       NaN
# 11          0.6868                  NaN                 NaN       NaN
# 39          0.4629               0.6291                 NaN       NaN
# 40          0.4533               0.6374                 NaN       NaN
# 33          0.4533               0.7186              0.8133    0.5794
# 34          0.4547               0.7185              0.8115    0.5804
# 35          0.4519               0.7187              0.8123    0.5799
# 1           0.3832               0.7544              0.8734    0.5483
# 22          0.5014               0.6284              0.7088    0.6335
# 12          0.6690                  NaN                 NaN       NaN
# 23          0.4245               0.7257              0.8569    0.5569
# 24          0.4766               0.6992              0.8937    0.5378
# 41          0.4945               0.6552                 NaN       NaN
# 13          0.6236                  NaN                 NaN       NaN
# 36          0.3132               0.8977              1.2051    0.3768
# 37          0.2898               0.9651              1.8467    0.0450
#
#     threshold_socre                          type  family
# 14           0.9437      probs_avg_classification  Neural
# 15           0.9423      probs_avg_classification  Linear
# 25           0.9409                    regression  Neural
# 26           0.9382                    regression  Neural
# 16           0.9382      probs_avg_classification  Neural
# 17           0.9368      probs_avg_classification  Neural
# 27           0.9341                    regression  Neural
# 28           0.9327                    regression  Neural
# 29           0.9327                    regression  Neural
# 2            0.9327                classification  Neural
# 30           0.9313                    regression  Linear
# 18           0.9299      probs_avg_classification  Neural
# 19           0.9299      probs_avg_classification  Neural
# 3            0.9258                classification    Tree
# 4            0.9245                classification  Neural
# 5            0.9231                classification  Neural
# 6            0.9217                classification  Linear
# 20           0.9217      probs_avg_classification    Tree
# 21           0.9217      probs_avg_classification  Linear
# 31           0.9203                    regression    Tree
# 38           0.9203            ordinal_regression  Linear
# 7            0.9203                classification  Linear
# 0            0.9190  probs_avg_ordinal_regression  Linear
# 8            0.9162                classification  Linear
# 32           0.9148                    regression  Linear
# 10           0.9148                classification  Neural
# 9            0.9148                classification  Linear
# 11           0.9135                classification  Neural
# 39           0.9135            ordinal_regression  Linear
# 40           0.9121            ordinal_regression  Linear
# 33           0.9121                    regression  Linear
# 34           0.9107                    regression  Linear
# 35           0.9093                    regression  Linear
# 1            0.9038  probs_avg_ordinal_regression  Linear
# 22           0.9025      probs_avg_classification  Linear
# 12           0.9025                classification    Tree
# 23           0.8887      probs_avg_classification    Tree
# 24           0.8846      probs_avg_classification  Linear
# 41           0.8750            ordinal_regression  Linear
# 13           0.8654                classification  Linear
# 36           0.8201                    regression  Linear
# 37           0.7802                    regression  Linear

# %%
sns.pairplot(evaluation.dropna())

# %%
sns.clustermap(evaluation.corr().abs(), vmin=0)

# %%
from adjustText import adjust_text

colors = ['r', 'g', 'b', 'y', 'pink']

f, ax = plt.subplots(1, figsize=(10, 10))

make_handle = lambda m,c: plt.plot([],[],marker=m, color=c, ls="none")[0]
handles = []
labels = []
family2marker = {'Linear': '+',
                 'Tree': '1',
                 'Neural': 'x'}
type2color = dict(zip(evaluation['type'].unique(), colors))
        
for family, marker in family2marker.items():
    labels.append(family)
    handles.append(make_handle(marker, 'k'))

for type_, color in type2color.items():
    labels.append(type_)
    handles.append(make_handle('s', color))
   

for family, family_group in evaluation.groupby('family'):
    for type_, type_group in family_group.groupby('type'):
        type_group.plot(kind='scatter', x='accuracy_score', y='threshold_socre',
                        marker=family2marker[family], color=type2color[type_], s=100,
                        alpha=0.5,
                        ax=ax)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5),
          fancybox=True, shadow=True, fontsize=15)

texts = [ax.text(r['accuracy_score'], r['threshold_socre'], r['name'])
             for _, r in evaluation[evaluation['name'].str.match('(SV. rbf|MLP-deep)')].iterrows()]
    
adjust_text(texts);

ax.set_title('Features2Prediction Models Comparison')

f.savefig('models-comparison', dpi=300)
